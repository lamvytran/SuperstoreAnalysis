# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import plotly.express as px
import numpy as np

# %%
from plotly.offline import init_notebook_mode
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
superstore = pd.read_csv('/Users/zit/Downloads/Superstore/train.csv')

# %%
superstore.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
superstore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
superstore[superstore["Postal Code"].isnull()]
#Null Postal Code all related to state Vermont
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
#Find postal code of State vermont and fill in the data set
superstore['Postal Code'].fillna(5401, inplace= True)

# %%
#Check duplicated value
superstore[superstore.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, Country, City, State, Postal Code, Region, Product ID, Category, Sub-Category, Product Name, Sales]
# Index: []

# %%
superstore['Order Date']=pd.to_datetime(superstore['Order Date'],dayfirst=True,infer_datetime_format=True, format='d%m%Y')
superstore['Ship Date']=pd.to_datetime(superstore['Ship Date'],dayfirst=True,infer_datetime_format=True,format='d%m%Y')

# %%
#create a processing days column which present the time range between the Order Date and Ship Date
superstore['Processing Days']= superstore['Ship Date']- superstore['Order Date']
superstore['Processing Days'].describe()
# Out:
# count                         9800
# mean     3 days 23:04:00.979591836
# std      1 days 17:59:26.617201004
# min                0 days 00:00:00
# 25%                3 days 00:00:00
# 50%                4 days 00:00:00
# 75%                5 days 00:00:00
# max                7 days 00:00:00
# Name: Processing Days, dtype: object

# %%
#Chart 1: SALES BY SHIP MODE
ship_modes = ['First Class', 'Same Day', 'Second Class', 'Standard Class']
order_counts1 = superstore.groupby('Ship Mode').count()['Segment']
colors1 = ['#66b3ff', '#c7b3fb','#ff6666', '#f9c3b7']

fig, ax = plt.subplots(figsize =(10,7))
ax.pie(order_counts1, labels = ship_modes, colors=colors1,autopct='%1.2f%%', startangle=90)
ax.set_title('Percentage of Orders by Ship Mode')
ax.axis('equal')


plt.show()

# %%
#Number of Orders by Segment
order_segment = superstore.groupby('Segment').count().reset_index()
fig, ax = plt.subplots(figsize=(10,7))
ax.bar(order_segment['Segment'], order_segment['Sales'], color = '#004577')

ax.set_title('Number of Orders by Segment')
ax.set_xlabel('Segment')
ax.set_ylabel('Total Orders')
# Out:
# Text(0, 0.5, 'Total Orders')

# %%
#Chart 3: Sales by Category
sale_category = superstore.groupby('Category')['Sales'].sum().reset_index()
colors2 = ['#ff6666', '#99ff99', '#66b3ff']

fig, ax = plt.subplots(figsize =(10,7))
ax.pie(sale_category['Sales'], labels = sale_category['Category'], colors=colors2,autopct='%1.2f%%', startangle=90)
ax.set_title('Percentage of Sales by Category')
ax.axis('equal')

plt.show()

# %%
#
category_fur = superstore[superstore['Category']=='Furniture']
category_tech = superstore[superstore['Category']=='Technology']
category_sup = superstore[superstore['Category']=='Office Supplies']
sale_scategory1 = category_fur.groupby('Sub-Category')['Sales'].sum().reset_index()
sale_scategory2 = category_tech.groupby('Sub-Category')['Sales'].sum().reset_index()
sale_scategory3 = category_sup.groupby('Sub-Category')['Sales'].sum().reset_index()

# %%
wedges, texts, autotexts = ax.pie(order_counts, autopct='%1.1f%%', startangle=90)
legends = [f'{mode}: {count}' for mode, count in zip(ship_modes, order_counts1)]
ax.legend(wedges, legends, loc='best')

# %%
#Chart4
colors3 = ['#ff6163', '#ff000d', '#770001','#fdc1c5']
fig, ax = plt.subplots(figsize =(8,5))
ax.pie(sale_scategory1['Sales'],labels = sale_scategory1['Sub-Category'], colors=colors3,autopct='%1.f%%', startangle=90)
ax.set_title('Total Sales by Sub-Category in Furniture')
ax.axis('equal')
plt.show()
#Chart5
colors4 = ['#115084', '#9dbcd4', '#95d0fc','#5b7c99']
fig, ax = plt.subplots(figsize =(8,5))
ax.pie(sale_scategory2['Sales'], labels = sale_scategory2['Sub-Category'], colors=colors4,autopct='%1.f%%', startangle=90)
ax.set_title('Total Sales by Sub-Category in Technology')
ax.axis('equal')
plt.show()
#Chart6
colors5 = ['#02ab2e', '#98f6b0', '#54ac68','#658d6d','#2dfe54','#2b5d34','#06470c','#76ff7b','#b6ffbb']
fig, ax = plt.subplots(figsize =(8,5))
ax.pie(sale_scategory3['Sales'], labels = sale_scategory3['Sub-Category'], colors=colors5,autopct='%1.f%%', startangle=90)
ax.set_title('Total Sales by Sub-Category in Office Supplies')
ax.axis('equal')

plt.show()

# %%
superstore['Year'] = pd.DatetimeIndex(superstore['Order Date']).year
superstore['Month'] = pd.DatetimeIndex(superstore['Order Date']).month
superstore.head(5)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
#Total sales per month
year_list = [2015, 2016, 2017, 2018]

sales_data = pd.DataFrame()

for year in year_list:
    sales_year = superstore[superstore['Year'] == year]
    sales_monthly = sales_year.groupby('Month')['Sales'].sum().reset_index()
    sales_monthly['Year'] = year
    sales_data = pd.concat([sales_data, sales_monthly])

fig, ax = plt.subplots(figsize=(12,7))
for year in year_list:
    data = sales_data[sales_data['Year'] == year]
    ax.plot(data['Month'], data['Sales'], label=str(year), marker='o')

ax.set_title('Total Sales by Month')
ax.set_xlabel('Month')
ax.set_ylabel('Sales')
ax.legend()

plt.show()

# %%
yearly_sales = sales_data.groupby('Year')['Sales'].sum().reset_index()
yearly_sales['Growth rate']= yearly_sales['Sales'].pct_change(periods=1) * 100
yearly_sales
# Out:
#    Year        Sales  Growth rate
# 0  2015  479856.2081          NaN
# 1  2016  459436.0054    -4.255484
# 2  2017  600192.5500    30.636812
# 3  2018  722052.0192    20.303396

# %%
#Top 10 cities with highest sales
top_sales= superstore.groupby("City").sum().sort_values("Sales",ascending=False).head(10)
top_sales.reset_index(inplace=True)
cities = top_sales['City']
sales = top_sales['Sales']

fig, ax = plt.subplots(figsize=(10,7))
ax.bar(cities, sales, color = '#004577')

ax.set_title('Top 10 Cities with Highest Total Sales')
ax.set_xlabel('City')
ax.set_ylabel('Sales')

plt.xticks(rotation=45)

plt.show()

# %%
#Top Cities have highest sales by category
top_cities = superstore.groupby(['City','Category']).sum().sort_values('Sales', ascending=False).head(23)
top_cities.reset_index(inplace=True)
plt.figure(figsize=(15,7))
sns.barplot(x='City',y='Sales',hue='Category',data=top_cities,palette='Reds_r')
plt.xticks(rotation='vertical')
plt.title('Top Cities having the highest total sales by Category')
plt.show()

# %% [markdown]
# ***Insights***
# - For shipping mode, Standard class is the most popular, taking over 50% of the orders, followed by Second Class, First Class, and Same Day. The Processing Days (time range between the Order date and Ship date) have a range from 0-7 days and most are around 3 days.
# - For sales, our main customer is **direct consumer**, the second place is corporate and the last position is home office.
# - Sales by categories are not very different. **Technology is the largest with 36.6%, followed by Furniture (32.2%) and Office Supplies ( 31.2%)**
# - According to revenue, each category also has its own dominant sub-category product. For technology is Phones, furniture is Chair, and Office Supplies is Storage.
# - The distribution of sales during one year seems to follow a similar pattern, which reak a peak in **March, September, and November.**
# - Among 4 years under research, the growth rate in 2016 was negative. Although the **growth rate in 2017, and 2018 are all good, the revenue growth in 2018 tends to grow slower than it did in 2017**.
# - The top 3 Cities that gain the highest revenue are **New York City, Los Angeles, and Seattle**. Most orders come from the Technology category, followed by Furniture and Office Supplies. This trend applies to all three cities.
